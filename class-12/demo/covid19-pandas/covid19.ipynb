# %% [markdown]
# # COVID 19 with Pandas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd

# %%
df = pd.read_csv('worldwide_covid_data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0    Afghanistan       156397          7290         128982.0       20125.0
# 1        Albania       190125          2970         178998.0        8157.0
# 2        Algeria       207385          5954         142332.0       59099.0
# 3        Andorra        15717           130          15392.0         195.0
# 4         Angola        64762          1723          61092.0        1947.0
# ..           ...          ...           ...              ...           ...
# 191    Venezuela       414220          4976         399768.0        9476.0
# 192      Vietnam       984805         22686         842800.0      119319.0
# 193        Yemen         9891          1915           6571.0        1405.0
# 194       Zambia       209918          3664         206091.0         163.0
# 195     Zimbabwe       133242          4691         128153.0         398.0
#
#      Total Cases/1M population  Deaths/1M population  Total Tests  \
# ...

# %%
df.head(10)
# Out:
#                Country  Total Cases  Total Deaths  Total Recovered  \
# 0          Afghanistan       156397          7290         128982.0
# 1              Albania       190125          2970         178998.0
# 2              Algeria       207385          5954         142332.0
# 3              Andorra        15717           130          15392.0
# 4               Angola        64762          1723          61092.0
# 5  Antigua and Barbuda         4091           105           3852.0
# 6            Argentina      5299418        116165        5166251.0
# 7              Armenia       322364          6762         285057.0
# 8                Aruba        16011           172          15702.0
# 9            Australia       182870          1841         160511.0
#
#    Active Cases  Total Cases/1M population  Deaths/1M population  Total Tests  \
# 0       20125.0                       3899                   182     777578.0
# ...

# %%
df.tail(10)
# Out:
#         Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 186          UK      9366676        142124        7665532.0     1559020.0
# 187     Ukraine      3107489         73390        2537565.0      496534.0
# 188     Uruguay       395610          6093         387392.0        2125.0
# 189         USA     47536536        778316       37604540.0     9153680.0
# 190  Uzbekistan       188398          1343         184507.0        2548.0
# 191   Venezuela       414220          4976         399768.0        9476.0
# 192     Vietnam       984805         22686         842800.0      119319.0
# 193       Yemen         9891          1915           6571.0        1405.0
# 194      Zambia       209918          3664         206091.0         163.0
# 195    Zimbabwe       133242          4691         128153.0         398.0
#
#      Total Cases/1M population  Deaths/1M population  Total Tests  \
# 186                     137001                  2079  341791652.0
# ...

# %%
df.keys()
# Out:
# Index(['Country', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Total Cases/1M population', 'Deaths/1M population',
#        'Total Tests', 'Tests/1M population', 'Population'],
#       dtype='object')

# %% [markdown]
# ## Jordan Data

# %%
jordan_data = df [ df['Country'] == 'Jordan' ]

# %%
jordan_data
# Out:
#    Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 93  Jordan       880943         11156         843602.0       26185.0
#
#     Total Cases/1M population  Deaths/1M population  Total Tests  \
# 93                      85195                  1079   11280788.0
#
#     Tests/1M population  Population
# 93            1090949.0    10340344

# %%
active_cases_jordan = jordan_data['Active Cases']

# %%
type(active_cases_jordan)
# Out:
# pandas.core.series.Series

# %%
print(active_cases_jordan)
# Out:
# 93    26185.0
# Name: Active Cases, dtype: float64

# %% [markdown]
# ### Extract the value from df series

# %%
active_cases_jordan.values[0]
# Out:
# 26185.0

# %% [markdown]
# ### Access By index

# %%
df.iloc[5]
# Out:
# Country                      Antigua and Barbuda
# Total Cases                                 4091
# Total Deaths                                 105
# Total Recovered                           3852.0
# Active Cases                               134.0
# Total Cases/1M population                  41312
# Deaths/1M population                        1060
# Total Tests                              17674.0
# Tests/1M population                     178475.0
# Population                                 99028
# Name: 5, dtype: object

# %% [markdown]
# ## Describe the data

# %%
df.describe()
# Out:
#         Total Cases   Total Deaths  Total Recovered  Active Cases  \
# count  1.960000e+02     196.000000     1.940000e+02  1.940000e+02
# mean   1.283176e+06   25913.336735     1.164880e+06  9.486610e+04
# std    4.633190e+06   85571.555469     4.086377e+06  6.703730e+05
# min    2.623000e+03       3.000000     5.500000e+01 -1.934000e+03
# 25%    2.265575e+04     334.750000     1.600000e+04  8.297500e+02
# 50%    1.824030e+05    2435.500000     1.421360e+05  7.133500e+03
# 75%    6.641715e+05   11974.500000     6.146435e+05  3.370050e+04
# max    4.753654e+07  778316.000000     3.760454e+07  9.153680e+06
#
#        Total Cases/1M population  Deaths/1M population   Total Tests  \
# count                 196.000000            196.000000  1.920000e+02
# mean                57058.724490            927.545918  2.128073e+07
# std                 52966.988865            970.235426  7.621579e+07
# min                    68.000000              3.000000  1.468900e+04
# ...

# %%
df.mean()
# Out:
# Total Cases                  1.283176e+06
# Total Deaths                 2.591334e+04
# Total Recovered              1.164880e+06
# Active Cases                 9.486610e+04
# Total Cases/1M population    5.705872e+04
# Deaths/1M population         9.275459e+02
# Total Tests                  2.128073e+07
# Tests/1M population          1.100628e+06
# Population                   4.009353e+07
# dtype: float64

# %%
df.mean()['Total Cases']
# Out:
# 1283176.3520408163

# %%
df[['Total Cases', 'Total Tests', 'Total Recovered']].mean()
# Out:
# Total Cases        1.283176e+06
# Total Tests        2.128073e+07
# Total Recovered    1.164880e+06
# dtype: float64

# %% [markdown]
# ## List of coutries where Total Deaths > 40000 sorted by Total Deaths. Show only country name and total daeths and total cases columns?

# %%
# Data where total deaths > 40000
biggest_deaths = df[ df['Total Deaths'] > 40000 ]

# %%
biggest_deaths.describe()
# Out:
#         Total Cases   Total Deaths  Total Recovered  Active Cases  \
# count  2.100000e+01      21.000000     2.000000e+01  2.000000e+01
# mean   9.169127e+06  194820.285714     8.584952e+06  7.376987e+05
# std    1.157839e+07  193003.747352     1.014899e+07  2.016793e+06
# min    1.718726e+06   44567.000000     1.521696e+06  9.602000e+03
# 25%    3.125179e+06   87558.000000     3.099454e+06  5.319550e+04
# 50%    5.019158e+06  127551.000000     4.873052e+06  1.676135e+05
# 75%    8.288165e+06  200469.000000     7.631080e+06  3.709220e+05
# max    4.753654e+07  778316.000000     3.760454e+07  9.153680e+06
#
#        Total Cases/1M population  Deaths/1M population   Total Tests  \
# count                  21.000000             21.000000  2.100000e+01
# mean                77656.761905           1938.523810  1.296427e+08
# std                 36238.115254           1181.611722  1.961372e+08
# min                 15314.000000            330.000000  1.147105e+07
# ...

# %%
sorted_by_total_deaths = biggest_deaths.sort_values(by='Total Deaths', ascending=False)

# %%
sorted_by_total_deaths
# Out:
#           Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 189           USA     47536536        778316       37604540.0     9153680.0
# 25         Brazil     21897025        609816       21100888.0      186321.0
# 83          India     34386786        461827       33776053.0      148906.0
# 117        Mexico      3827596        289811        3193068.0      344717.0
# 148        Russia      8873655        249215        7619596.0     1004844.0
# 141          Peru      2207890        200469              NaN           NaN
# 84      Indonesia      4248843        143578        4095663.0        9602.0
# 186            UK      9366676        142124        7665532.0     1559020.0
# 89          Italy      4818705        132491        4586009.0      100205.0
# 39       Colombia      5019158        127610        4862352.0       29196.0
# 85           Iran      6004460        127551        5629596.0      247313.0
# ...

# %%
final_result = sorted_by_total_deaths[['Country','Total Deaths','Total Cases']]

# %%
final_result
# Out:
#           Country  Total Deaths  Total Cases
# 189           USA        778316     47536536
# 25         Brazil        609816     21897025
# 83          India        461827     34386786
# 117        Mexico        289811      3827596
# 148        Russia        249215      8873655
# 141          Peru        200469      2207890
# 84      Indonesia        143578      4248843
# 186            UK        142124      9366676
# 89          Italy        132491      4818705
# 39       Colombia        127610      5019158
# 85           Iran        127551      6004460
# 63         France        118023      7232157
# 6       Argentina        116165      5299418
# 69        Germany         97355      4830135
# 165  South Africa         89387      2924317
# 167         Spain         87558      5032056
# 143        Poland         77980      3125179
# 187       Ukraine         73390      3107489
# 183        Turkey         72510      8288165
# 147       Romania         51483      1718726
# ...
