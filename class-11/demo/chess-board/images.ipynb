# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('onion.png')

# %%
img.shape
# Out:
# (800, 787, 4)

# %%
img[400,400]
# Out:
# array([0.85882354, 0.58431375, 0.36862746, 1.        ], dtype=float32)

# %%
plt.imshow(img) #Render the image

# %%
plt.imshow(img[:300,:300])

# %%
plt.imshow(img[400:,400:])

# %%
converted_image = plt.imshow(np.dot(img[...,:3], [0.7, 0.7, 0.3]))
